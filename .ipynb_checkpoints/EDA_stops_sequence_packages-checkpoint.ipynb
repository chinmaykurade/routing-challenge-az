# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Importing the route data

# %%
# Get Directory
BASE_DIR = "D:/Code/RoutingChallenge/routing-challenge-az"

training_routes_path=os.path.join(BASE_DIR, 'data/model_build_inputs/route_data.json')

# Read route data
print('Reading Input Data')
df_route_data = pd.read_json(training_routes_path).T
# Out:
# Reading Input Data

# %%
df_route_data.shape
# Out:
# (6112, 6)

# %%
df_route_data.head()
# Out:
#                                              station_code date_YYYY_MM_DD  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77         DLA3      2018-07-27
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59         DSE4      2018-07-28
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f         DSE5      2018-08-18
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f         DLA9      2018-08-15
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523         DLA7      2018-08-05
#
#                                              departure_time_utc  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           16:02:10
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           15:44:41
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f           15:32:04
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f           15:09:38
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523           14:23:26
#
#                                              executor_capacity_cm3  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77             3313071.0
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59             4247527.0
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f             4247527.0
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f             3313071.0
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523             3313071.0
#
#                                              route_score  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77        High
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59        High
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f        High
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f        High
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523        High
#
#                                                                                           stops
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77  {'AD': {'lat': 34.099611, 'lng': -118.283062, ...
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59  {'AC': {'lat': 47.689446, 'lng': -122.296071, ...
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f  {'AA': {'lat': 47.268001, 'lng': -122.5079, 't...
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f  {'AB': {'lat': 33.823076, 'lng': -118.058727, ...
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523  {'AA': {'lat': 33.84364, 'lng': -117.773651, '...

# %%
df_route_data['num_stops'] = df_route_data['stops'].apply(lambda x: len(x))

# %%
df_stops = df_route_data[['station_code','stops','num_stops']]

# %%
df_stops.head()
# Out:
#                                              station_code  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77         DLA3
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59         DSE4
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f         DSE5
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f         DLA9
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523         DLA7
#
#                                                                                           stops  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77  {'AD': {'lat': 34.099611, 'lng': -118.283062, ...
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59  {'AC': {'lat': 47.689446, 'lng': -122.296071, ...
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f  {'AA': {'lat': 47.268001, 'lng': -122.5079, 't...
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f  {'AB': {'lat': 33.823076, 'lng': -118.058727, ...
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523  {'AA': {'lat': 33.84364, 'lng': -117.773651, '...
#
#                                               num_stops
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77        119
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59        106
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f        128
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f        142
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523        155

# %% [markdown]
# What does a stop look like?

# %%
pd.DataFrame(df_stops.iloc[0,:]['stops']).T.head()
# Out:
#           lat         lng     type  zone_id
# AD  34.099611 -118.283062  Dropoff  P-12.3C
# AF  34.101587 -118.291125  Dropoff   A-1.2D
# AG  34.089727  -118.28553  Dropoff   A-2.1A
# BA  34.096132 -118.292869  Dropoff   A-1.2C
# BE  34.098482 -118.286243  Dropoff  P-13.3B

# %% [markdown]
# ## Visualizing the stops on a graph
# Here, we exclude the station since it distorts the graph

# %%
def visualize_stops(df_stops,i,exclude_station=True):
    stops = pd.DataFrame(df_stops.iloc[i,:]['stops']).T
    station = stops[stops['type']=='Station']
    if exclude_station:        
        stops = stops[stops['type']!='Station']
#     print(stops)
    plt.figure(figsize=(10,7),dpi=300)
    plt.scatter(stops['lat'],stops['lng'])
    plt.xlabel("Latitude")
    plt.ylabel("Longitude")
    plt.title(f"Stops for route: {df_stops.index[i]}")
    plt.show()
    print(f"Station data:\nLatitude:{station.iloc[0,0]:13}")
    print(f"Longitude:{station.iloc[0,1]:13}")

# %%
i=54
visualize_stops(df_stops,i,exclude_station=True)
# Out:
# Station data:
# Latitude:    33.965477
# Longitude:  -117.653303

# %% [markdown]
# ## Getting the actual route sequence data

# %%
training_routes_seq=os.path.join(BASE_DIR, 'data/model_build_inputs/actual_sequences.json')

# Read route data
print('Reading Input Data')
df_seq = pd.read_json(training_routes_seq).T
# Out:
# Reading Input Data

# %%
df_seq.shape
# Out:
# (6112, 1)

# %%
def visualize_route_seq(df_stops,df_seq,i,exclude_station=True):
    stops = pd.DataFrame(df_stops.iloc[i,:]['stops']).T
    station = stops[stops['type']=='Station']
    if exclude_station:        
        stops = stops[stops['type']!='Station']
#     print(stops)
    plt.figure(figsize=(10,7),dpi=300)
#     plt.scatter(stops['lat'],stops['lng'])
    plt.xlabel("Latitude")
    plt.ylabel("Longitude")
    plt.title(f"Stops for route: {df_stops.index[i]}")
#     plt.show()
    print(f"Station data:\nLatitude:{station.iloc[0,0]:13}")
    print(f"Longitude:{station.iloc[0,1]:13}")
    
    seq = pd.Series(df_seq.iloc[i,0]).sort_values().index.to_list()
    if exclude_station:
        seq = seq[1:]
    plt.plot(stops['lat'][seq],stops['lng'][seq],'.-')

# %%
i=10
visualize_route_seq(df_stops,df_seq,i,exclude_station=True)
# Out:
# Station data:
# Latitude:    33.918699
# Longitude:  -118.324843

# %% [markdown]
# ### We also want to visualize the time windows

# %%
packages_path=os.path.join(BASE_DIR, 'data/model_build_inputs/package_data.json')

# Read route data
print('Reading Input Data')
df_pkg = pd.read_json(packages_path).T
# Out:
# Reading Input Data

# %%
df_pkg.shape
# Out:
# (6112, 675)

# %%
def get_time_windows_package(pkgs, handle_mismatch='intersection',verbose=False):
    time_windows = {}
    start,end = None,None
#     print(pkgs)
    if pkgs is np.nan:
        return None
    for idd,pkg in pkgs.items():
        if verbose:
            print(start,end)
        time_window = pkg['time_window']
        if verbose: 
            print('>>',end='   ')
            print(time_window['start_time_utc'],end='   ')
            print(time_window['end_time_utc'])
        if start is None and end is None:
            start = time_window['start_time_utc']
            end = time_window['end_time_utc']
            if start is not None:
                start = np.datetime64(start)
            if end is not None:
                end = np.datetime64(end)
        else:
            new_start = time_window['start_time_utc']
            new_end = time_window['end_time_utc']
            
            if new_start is not None:
                new_start = np.datetime64(new_start)
            if new_end is not None:
                new_end = np.datetime64(new_end)
                
            if new_start != start and new_start is not None:
                if new_start > end:
                    print(f"Start times mismatch for {idd}")
                else:
                    start = min(start, new_start)
            if new_end != end and new_end is not None:
                if new_end < start:
                    print(f"End times mismatch for {idd}")
                else:
                    end = max(end, new_end)
                
#     print(start,end)
#     print(type(start))
    if start is None or end is None:
        return None
    return start,end

def get_time_windows_all(df_pkg):
    df_tw = df_pkg.copy()
    for route in df_pkg.index:
#         print(route)
#         print(df_pkg.loc[route,:])
        df_tw.loc[route,:] = df_pkg.loc[route,:].apply(lambda x: get_time_windows_package(x))
    return df_tw

# %%
df_tw = get_time_windows_all(df_pkg)
df_istw = df_tw.fillna(0)

# %%
def stops_having_tw(istw, seq):
    twlist = []
#     print(trimmed)
    for stop in seq:
#         print(stop)
        if istw[stop] != 0:
            twlist.append(stop)
    return twlist

# %%
def visualize_route_seq_tw(df_stops,df_seq,df_tw,i,exclude_station=True):
    stops = pd.DataFrame(df_stops.iloc[i,:]['stops']).T
    station = stops[stops['type']=='Station']
    if exclude_station:        
        stops = stops[stops['type']!='Station']
#     print(stops)
    plt.figure(figsize=(10,7),dpi=300)
#     plt.scatter(stops['lat'],stops['lng'])
    plt.xlabel("Latitude")
    plt.ylabel("Longitude")
    plt.title(f"Stops for route: {df_stops.index[i]}")
    
    seq = pd.Series(df_seq.iloc[i,0]).sort_values().index.to_list()
    if exclude_station:
        seq = seq[1:]
    plt.plot(stops['lat'][seq],stops['lng'][seq],'.-')
    
    istw = df_istw.iloc[i,:]
    # print(istw)
    list_stops_tw = stops_having_tw(istw, seq)
    stops_tw = stops.loc[list_stops_tw,:]
    plt.scatter(stops_tw['lat'],stops_tw['lng'],color = 'red')
    
    plt.text(stops['lat'][seq[0]],stops['lng'][seq[0]],'start')
    plt.text(stops['lat'][seq[-1]],stops['lng'][seq[-1]],'end')
    
    plt.show()
    print(f"Station data:\nLatitude:{station.iloc[0,0]:13}")
    print(f"Longitude:{station.iloc[0,1]:13}")

# %%
i = 5005
visualize_route_seq_tw(df_stops,df_seq,df_tw,i,exclude_station=True)
# Out:
# Station data:
# Latitude:    33.918699
# Longitude:  -118.324843

# %% [markdown]
# Red dots indicate whether time windows exist
