# %%
import numpy as np
import pandas as pd
from os import path
import math

# %%
import sys, json, time

# %%
#BASE_DIR = path.dirname(path.dirname(path.abspath('data/')))

# %%
# Read input data
#print('Reading Input Data')
#training_routes_path=path.join( 'data/model_build_inputs/route_data.json')
#with open(training_routes_path, newline='') as in_file:
#    actual_routes = json.load(in_file)

# %%
pd.set_option('display.max_columns', None)

# %%
location1='data/model_build_inputs/route_data.json'
df1=pd.read_json(location1).T
df1=df1.rename_axis("Route_ID", axis="columns")

# %%
df1.head()
# Out:
# Route_ID                                     station_code date_YYYY_MM_DD  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77         DLA3      2018-07-27
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59         DSE4      2018-07-28
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f         DSE5      2018-08-18
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f         DLA9      2018-08-15
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523         DLA7      2018-08-05
#
# Route_ID                                     departure_time_utc  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           16:02:10
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           15:44:41
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f           15:32:04
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f           15:09:38
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523           14:23:26
#
# Route_ID                                     executor_capacity_cm3  \
# ...

# %%
location2='data/model_build_inputs/actual_sequences.json'
df2=pd.read_json(location2).T
df2=df2.rename_axis("Route_ID", axis="columns")

# %%
df2.head()
# Out:
# Route_ID                                                                                 actual
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77  {'AD': 105, 'AF': 47, 'AG': 4, 'BA': 33, 'BE':...
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59  {'AC': 36, 'AE': 28, 'AG': 104, 'AN': 94, 'AS'...
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f  {'AA': 58, 'AD': 94, 'AJ': 41, 'AP': 124, 'AR'...
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f  {'AB': 122, 'AC': 39, 'AG': 27, 'AI': 16, 'AU'...
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523  {'AA': 43, 'AB': 54, 'AF': 72, 'AG': 31, 'AI':...

# %%
location3='data/model_build_inputs/package_data.json'
df3=pd.read_json(location3).T
df3=df3.rename_axis("Route_ID", axis="columns")

# %%
df3.head()
# Out:
# Route_ID                                                                                     AD  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77  {'PackageID_9d7fdd03-f2cf-4c6f-9128-028258fc09...
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59                                                NaN
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f  {'PackageID_de2b05b8-2186-47b2-b0f1-640cd01b65...
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f                                                NaN
# RouteID_0021a2aa-780f-460d-b09a-f301709e2523                                                NaN
#
# Route_ID                                                                                     AF  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77  {'PackageID_15c6a204-ec5f-4ced-9c3d-472316cc77...
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59                                                NaN
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f                                                NaN
# ...

# %%
col_stops=df3.columns

# %%
col_stops
# Out:
# Index(['AD', 'AF', 'AG', 'BA', 'BE', 'BG', 'BP', 'BT', 'BY', 'BZ',
#        ...
#        'GG', 'PH', 'EN', 'QN', 'SG', 'SX', 'SU', 'UK', 'VK', 'BN'],
#       dtype='object', name='Route_ID', length=675)

# %%
#route=pd.DataFrame(actual_routes)

# %%
#df=pd.merge(df1,df2,on='Route_ID')
df=df1.join(df3)
df=df.join(df2)

# %%
df.head(4)
# Out:
# Route_ID                                     station_code date_YYYY_MM_DD  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77         DLA3      2018-07-27
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59         DSE4      2018-07-28
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f         DSE5      2018-08-18
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f         DLA9      2018-08-15
#
# Route_ID                                     departure_time_utc  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           16:02:10
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           15:44:41
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f           15:32:04
# RouteID_001b4ee3-c4f2-467f-932b-c85524d1021f           15:09:38
#
# Route_ID                                     executor_capacity_cm3  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           3.31307e+06
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           4.24753e+06
# RouteID_001948e9-4675-486d-9ec5-912fd8e0770f           4.24753e+06
# ...

# %%
for col in col_stops:
    for i in range(6112):
        try:
            if math.isnan(df[col][i]):
                df[col][i]=0
        except:
            df[col][i]=len(list(map(lambda x:df[col][i][x]['scan_status'],df[col][i].keys())))
            #print(a)
            #print(i)
        
    
 #   if math.isnan(df['AD'][i]):
  #      print(i)
   #     #a=list(map(lambda x:df['AD'][i][x]['scan_status'],df['AD'][i].keys()))

# %%
df.head(2)
# Out:
# Route_ID                                     station_code date_YYYY_MM_DD  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77         DLA3      2018-07-27
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59         DSE4      2018-07-28
#
# Route_ID                                     departure_time_utc  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           16:02:10
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           15:44:41
#
# Route_ID                                     executor_capacity_cm3  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77           3.31307e+06
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59           4.24753e+06
#
# Route_ID                                     route_score  \
# RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77        High
# RouteID_0016bc70-cb8d-48b0-aa55-8ee50bdcdb59        High
#
# Route_ID                                                                                  stops  \
# ...

# %%
df.to_json(r'E:\RoutineChallenge\Coding\data\Preprocessed_data\preprocessed_firstStage.json')

# %%
pd.DataFrame(df['AD']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6112 entries, RouteID_00143bdd-0a6b-49ec-bb35-36593d303e77 to RouteID_fffd257c-3041-4736-be7a-5efea8af1173
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AD      1294 non-null   object
# dtypes: object(1)
# memory usage: 255.5+ KB

# %%
df.describe()
# Out:
# Route_ID station_code date_YYYY_MM_DD departure_time_utc  \
# count            6112            6112               6112
# unique             17              39               4535
# top              DLA7      2018-08-14           16:00:00
# freq             1133             297                178
#
# Route_ID  executor_capacity_cm3 route_score  \
# count                    6112.0        6112
# unique                      3.0           3
# top                   3313071.0      Medium
# freq                     4175.0        3292
#
# Route_ID                                              stops    AD  \
# count                                                  6112  1294
# unique                                                 6112  1284
# top       {'AD': {'lat': 47.356622, 'lng': -122.173216, ...    {}
# freq                                                      1    11
#
# Route_ID                                                 AF    AG    BA    BE  \
# ...

# %%
df['stops'][1]
# Out:
# {'AC': {'lat': 47.689446,
#   'lng': -122.296071,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.2A'},
#  'AE': {'lat': 47.683039,
#   'lng': -122.292498,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.1A'},
#  'AG': {'lat': 47.676683,
#   'lng': -122.30768,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.3C'},
#  'AN': {'lat': 47.673579,
#   'lng': -122.3065,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.3C'},
#  'AS': {'lat': 47.678486,
#   'lng': -122.303892,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.1B'},
#  'BA': {'lat': 47.684871,
#   'lng': -122.297748,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.3A'},
#  'BF': {'lat': 47.677761,
#   'lng': -122.297395,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.3A'},
#  'BJ': {'lat': 47.680784,
#   'lng': -122.304998,
#   'type': 'Dropoff',
#   'zone_id': 'D-2.1B'},
#  'BP': {'lat': 47.683784,
#   'lng': -122.290503,
#   'type': 'Dropoff',
#   'zone_id': 'D-3.2A'},
#  'BV': {'lat': 47.680504,
#   'lng': -122.302865,
#   'type': 'Dropoff',
# ...
